# %% [markdown]
# # Custom CNN for HER2 IHC Image Classification
# ## Info
# ### Version: V1.1.1
# #### Changes:
# Changes from V1.0.0 has been made on the epoch number(100 epochs) and the Accuracy has been improved too!

# %%
# Version information
version_info = """
Project Version: 1.0.0
Release Date: 2025-01-15
Author: Saky
"""

# %%
# Write to version.txt
with open("/kaggle/working/version.txt", "w") as f:
    f.write(version_info)

# Check the content by reading it back
with open("/kaggle/working/version.txt", "r") as f:
    print(f.read())
# Out:
# Project Version: 1.0.0
# Release Date: 2025-01-15
# Author: Saky

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import os
import shap
from keras.preprocessing import image
import tensorflow.keras.backend as K

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("GPU is enabled!")
else:
    print("GPU is not enabled.")
# Out:
# GPU is enabled!

# %%
# Path to your dataset
train_dir = "/kaggle/input/train-pvt-intnsty"
test_dir = "/kaggle/input/test-pvt-intnsty"

# Image dimensions
IMG_HEIGHT = 224
IMG_WIDTH = 224

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,               # Normalize pixel values
    rotation_range=40,               # Random rotations
    width_shift_range=0.2,           # Random horizontal shifts
    height_shift_range=0.2,          # Random vertical shifts
    shear_range=0.2,                 # Random shear
    zoom_range=0.2,                  # Random zoom
    horizontal_flip=True,            # Random horizontal flip
    fill_mode='nearest'              # Fill missing pixels
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=32,
    class_mode='categorical',        # Use categorical for multi-class classification
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=32,
    class_mode='categorical',        # Use categorical for multi-class classification
    shuffle=False
)
# Out:
# Found 9689 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.

# %%
def build_custom_cnn(input_shape=(224, 224, 3)):
    model = models.Sequential()
    
    # Convolutional Block 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D(2, 2))
    
    # Convolutional Block 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(2, 2))
    
    # Convolutional Block 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(2, 2))
    
    # Convolutional Block 4
    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(2, 2))
    
    # Flatten and Dense Layer
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))  # Dropout layer to reduce overfitting
    model.add(layers.Dense(4, activation='softmax'))  # 4 classes for multi-class classification
    
    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Build and summarize the model
model = build_custom_cnn()
model.summary()
# Out:
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      18,874,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           2,052 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,265,348 (73.49 MB)
#  Trainable params: 19,265,348 (73.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=100,  # Adjust epochs based on dataset size and performance
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size
)
# Out:
# Epoch 1/100
# Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 287s 911ms/step - accuracy: 0.6674 - loss: 0.7964 - val_accuracy: 0.8821 - val_loss: 0.3314
# Epoch 2/100
#   1/302 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.7812 - loss: 0.4250
# Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7812 - loss: 0.4250 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 585ms/step - accuracy: 0.8408 - loss: 0.4162 - val_accuracy: 0.8564 - val_loss: 0.3812
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 209us/step - accuracy: 0.8750 - loss: 0.3458 - val_accuracy: 1.0000 - val_loss: 7.1140e-04
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 587ms/step - accuracy: 0.8534 - loss: 0.3815 - val_accuracy: 0.8347 - val_loss: 0.4056
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 228us/step - accuracy: 0.8750 - loss: 0.3884 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 591ms/step - accuracy: 0.8591 - loss: 0.3754 - val_accuracy: 0.8362 - val_loss: 0.3896
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 222us/step - accuracy: 0.8438 - loss: 0.4660 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 180s 585ms/step - accuracy: 0.8607 - loss: 0.3594 - val_accuracy: 0.8942 - val_loss: 0.3648
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.8750 - loss: 0.3222 - val_accuracy: 1.0000 - val_loss: 3.1169e-05
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 184s 597ms/step - accuracy: 0.8592 - loss: 0.3584 - val_accuracy: 0.8584 - val_loss: 0.3447
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 227us/step - accuracy: 0.8750 - loss: 0.5316 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.8770 - loss: 0.3237 - val_accuracy: 0.8967 - val_loss: 0.2581
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - accuracy: 0.8750 - loss: 0.3627 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 589ms/step - accuracy: 0.8776 - loss: 0.3116 - val_accuracy: 0.9032 - val_loss: 0.2634
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 217us/step - accuracy: 0.8125 - loss: 0.4263 - val_accuracy: 0.9375 - val_loss: 0.1080
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.8825 - loss: 0.3134 - val_accuracy: 0.9022 - val_loss: 0.2783
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 244us/step - accuracy: 0.8125 - loss: 0.3719 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 585ms/step - accuracy: 0.8823 - loss: 0.3200 - val_accuracy: 0.8720 - val_loss: 0.3446
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 209us/step - accuracy: 0.9375 - loss: 0.1730 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 589ms/step - accuracy: 0.8843 - loss: 0.2953 - val_accuracy: 0.9163 - val_loss: 0.2398
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - accuracy: 0.9688 - loss: 0.1764 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 23/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 588ms/step - accuracy: 0.8801 - loss: 0.3053 - val_accuracy: 0.9229 - val_loss: 0.2263
# Epoch 24/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 212us/step - accuracy: 0.9062 - loss: 0.2802 - val_accuracy: 1.0000 - val_loss: 0.0840
# Epoch 25/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.8948 - loss: 0.2779 - val_accuracy: 0.9435 - val_loss: 0.1989
# Epoch 26/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 217us/step - accuracy: 0.8750 - loss: 0.2489 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 27/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 185s 600ms/step - accuracy: 0.8873 - loss: 0.2887 - val_accuracy: 0.9309 - val_loss: 0.2229
# Epoch 28/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 220us/step - accuracy: 0.9062 - loss: 0.2524 - val_accuracy: 1.0000 - val_loss: 8.4530e-05
# Epoch 29/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 179s 581ms/step - accuracy: 0.8975 - loss: 0.2860 - val_accuracy: 0.9103 - val_loss: 0.2623
# Epoch 30/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.8125 - loss: 0.3968 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 31/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 585ms/step - accuracy: 0.8925 - loss: 0.2809 - val_accuracy: 0.9355 - val_loss: 0.2225
# Epoch 32/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 208us/step - accuracy: 0.8750 - loss: 0.3162 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 33/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 586ms/step - accuracy: 0.9004 - loss: 0.2621 - val_accuracy: 0.9007 - val_loss: 0.2653
# Epoch 34/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 194us/step - accuracy: 0.9688 - loss: 0.1270 - val_accuracy: 1.0000 - val_loss: 0.0473
# Epoch 35/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 183s 593ms/step - accuracy: 0.9053 - loss: 0.2577 - val_accuracy: 0.9294 - val_loss: 0.2280
# Epoch 36/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - accuracy: 0.8750 - loss: 0.3093 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 37/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 179s 581ms/step - accuracy: 0.9121 - loss: 0.2434 - val_accuracy: 0.9214 - val_loss: 0.2335
# Epoch 38/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 230us/step - accuracy: 0.9375 - loss: 0.4140 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 39/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 586ms/step - accuracy: 0.9133 - loss: 0.2432 - val_accuracy: 0.9002 - val_loss: 0.2750
# Epoch 40/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - accuracy: 0.9062 - loss: 0.4179 - val_accuracy: 1.0000 - val_loss: 4.6688e-04
# Epoch 41/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 586ms/step - accuracy: 0.9026 - loss: 0.2525 - val_accuracy: 0.9199 - val_loss: 0.2297
# Epoch 42/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 230us/step - accuracy: 0.9688 - loss: 0.1286 - val_accuracy: 1.0000 - val_loss: 0.0251
# Epoch 43/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 587ms/step - accuracy: 0.9147 - loss: 0.2314 - val_accuracy: 0.9365 - val_loss: 0.2105
# Epoch 44/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 274us/step - accuracy: 0.9688 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 9.5117e-04
# Epoch 45/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 184s 595ms/step - accuracy: 0.9175 - loss: 0.2372 - val_accuracy: 0.9335 - val_loss: 0.2574
# Epoch 46/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.9688 - loss: 0.1600 - val_accuracy: 1.0000 - val_loss: 6.8545e-07
# Epoch 47/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 587ms/step - accuracy: 0.9122 - loss: 0.2378 - val_accuracy: 0.9259 - val_loss: 0.2823
# Epoch 48/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 221us/step - accuracy: 0.9062 - loss: 0.2933 - val_accuracy: 1.0000 - val_loss: 6.1094e-07
# Epoch 49/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 589ms/step - accuracy: 0.9114 - loss: 0.2389 - val_accuracy: 0.9083 - val_loss: 0.2399
# Epoch 50/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 226us/step - accuracy: 0.9062 - loss: 0.3192 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 51/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 185s 599ms/step - accuracy: 0.9253 - loss: 0.2119 - val_accuracy: 0.9360 - val_loss: 0.1863
# Epoch 52/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 216us/step - accuracy: 0.9688 - loss: 0.1027 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 53/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 184s 596ms/step - accuracy: 0.9188 - loss: 0.2175 - val_accuracy: 0.9234 - val_loss: 0.2895
# Epoch 54/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.8438 - loss: 0.1931 - val_accuracy: 1.0000 - val_loss: 4.0585e-05
# Epoch 55/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 184s 596ms/step - accuracy: 0.9204 - loss: 0.2252 - val_accuracy: 0.9309 - val_loss: 0.2377
# Epoch 56/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.8750 - loss: 0.3678 - val_accuracy: 1.0000 - val_loss: 5.4904e-05
# Epoch 57/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.9164 - loss: 0.2245 - val_accuracy: 0.9380 - val_loss: 0.2114
# Epoch 58/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 242us/step - accuracy: 0.9375 - loss: 0.1782 - val_accuracy: 1.0000 - val_loss: 1.4446e-04
# Epoch 59/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.9239 - loss: 0.2123 - val_accuracy: 0.9118 - val_loss: 0.2600
# Epoch 60/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.9375 - loss: 0.1317 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 61/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 179s 579ms/step - accuracy: 0.9187 - loss: 0.2215 - val_accuracy: 0.9123 - val_loss: 0.2554
# Epoch 62/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 231us/step - accuracy: 0.9688 - loss: 0.1125 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 63/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 183s 594ms/step - accuracy: 0.9284 - loss: 0.2037 - val_accuracy: 0.9229 - val_loss: 0.2175
# Epoch 64/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.9375 - loss: 0.2707 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 65/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 183s 592ms/step - accuracy: 0.9136 - loss: 0.2288 - val_accuracy: 0.9178 - val_loss: 0.2822
# Epoch 66/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.9688 - loss: 0.0706 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 67/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 589ms/step - accuracy: 0.9295 - loss: 0.1923 - val_accuracy: 0.9335 - val_loss: 0.2440
# Epoch 68/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 192us/step - accuracy: 0.8750 - loss: 0.2657 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 69/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 592ms/step - accuracy: 0.9314 - loss: 0.1990 - val_accuracy: 0.9304 - val_loss: 0.2262
# Epoch 70/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - accuracy: 0.9062 - loss: 0.2512 - val_accuracy: 1.0000 - val_loss: 8.7657e-04
# Epoch 71/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 589ms/step - accuracy: 0.9283 - loss: 0.2041 - val_accuracy: 0.9249 - val_loss: 0.2505
# Epoch 72/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 237us/step - accuracy: 0.8125 - loss: 0.8002 - val_accuracy: 1.0000 - val_loss: 0.0332
# Epoch 73/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.9236 - loss: 0.2045 - val_accuracy: 0.9304 - val_loss: 0.2802
# Epoch 74/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 244us/step - accuracy: 0.9688 - loss: 0.1465 - val_accuracy: 1.0000 - val_loss: 2.5267e-05
# Epoch 75/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 180s 581ms/step - accuracy: 0.9306 - loss: 0.1921 - val_accuracy: 0.9380 - val_loss: 0.1997
# Epoch 76/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.8750 - loss: 0.3956 - val_accuracy: 1.0000 - val_loss: 1.4664e-04
# Epoch 77/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.9302 - loss: 0.1913 - val_accuracy: 0.9037 - val_loss: 0.3329
# Epoch 78/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 269us/step - accuracy: 0.9062 - loss: 0.1747 - val_accuracy: 1.0000 - val_loss: 4.3584e-06
# Epoch 79/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 591ms/step - accuracy: 0.9271 - loss: 0.2038 - val_accuracy: 0.9365 - val_loss: 0.1926
# Epoch 80/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 231us/step - accuracy: 0.8750 - loss: 0.3587 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 81/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 586ms/step - accuracy: 0.9283 - loss: 0.1990 - val_accuracy: 0.9299 - val_loss: 0.2349
# Epoch 82/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 230us/step - accuracy: 0.9375 - loss: 0.1391 - val_accuracy: 1.0000 - val_loss: 2.2351e-06
# Epoch 83/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 586ms/step - accuracy: 0.9280 - loss: 0.1921 - val_accuracy: 0.9350 - val_loss: 0.2142
# Epoch 84/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 248us/step - accuracy: 0.9375 - loss: 0.1737 - val_accuracy: 1.0000 - val_loss: 4.8936e-04
# Epoch 85/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 180s 586ms/step - accuracy: 0.9330 - loss: 0.1872 - val_accuracy: 0.9516 - val_loss: 0.1833
# Epoch 86/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step - accuracy: 0.9375 - loss: 0.2624 - val_accuracy: 1.0000 - val_loss: 3.1330e-05
# Epoch 87/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 589ms/step - accuracy: 0.9318 - loss: 0.1876 - val_accuracy: 0.9239 - val_loss: 0.2108
# Epoch 88/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.9375 - loss: 0.1349 - val_accuracy: 1.0000 - val_loss: 4.7891e-04
# Epoch 89/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 589ms/step - accuracy: 0.9331 - loss: 0.1849 - val_accuracy: 0.9118 - val_loss: 0.3048
# Epoch 90/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 221us/step - accuracy: 0.9688 - loss: 0.0827 - val_accuracy: 1.0000 - val_loss: 2.5275e-05
# Epoch 91/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 181s 585ms/step - accuracy: 0.9386 - loss: 0.1733 - val_accuracy: 0.9219 - val_loss: 0.2658
# Epoch 92/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 215us/step - accuracy: 0.9062 - loss: 0.1433 - val_accuracy: 1.0000 - val_loss: 0.0473
# Epoch 93/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 182s 590ms/step - accuracy: 0.9293 - loss: 0.1931 - val_accuracy: 0.9395 - val_loss: 0.2193
# Epoch 94/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.9375 - loss: 0.1001 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 95/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 175s 568ms/step - accuracy: 0.9270 - loss: 0.1982 - val_accuracy: 0.9315 - val_loss: 0.2560
# Epoch 96/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 191us/step - accuracy: 1.0000 - loss: 0.0662 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 97/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 176s 571ms/step - accuracy: 0.9375 - loss: 0.1745 - val_accuracy: 0.9289 - val_loss: 0.2607
# Epoch 98/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 208us/step - accuracy: 0.9688 - loss: 0.1065 - val_accuracy: 1.0000 - val_loss: 1.1119e-04
# Epoch 99/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 175s 568ms/step - accuracy: 0.9318 - loss: 0.1832 - val_accuracy: 0.9395 - val_loss: 0.2011
# Epoch 100/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 172us/step - accuracy: 1.0000 - loss: 0.0357 - val_accuracy: 1.0000 - val_loss: 5.4147e-04

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test accuracy: {test_acc*100:.2f}%")
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.9272 - loss: 0.2655
# Test accuracy: 94.10%

# %% [markdown]
# # Prediction and Generating Reports

# %%
# Generate predictions for the validation or test set
predictions = model.predict(test_generator)  # Ensure you use the correct generator
predicted_classes = np.argmax(predictions, axis=1)

# Retrieve true labels from the generator
true_classes = test_generator.classes  # Ensure you use the same generator as in the prediction step

# Check the number of samples in true and predicted classes
print(f"Number of true labels: {len(true_classes)}")
print(f"Number of predicted labels: {len(predicted_classes)}")

# Ensure the lengths match
if len(true_classes) != len(predicted_classes):
    raise ValueError("Mismatch in number of true and predicted samples. Check the generator settings.")

# Get the class indices to use target names in the report
target_names = list(test_generator.class_indices.keys())

# Generate the classification report
from sklearn.metrics import classification_report
print(classification_report(true_classes, predicted_classes, target_names=target_names))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 283ms/step
# Number of true labels: 2000
# Number of predicted labels: 2000
#               precision    recall  f1-score   support
#
#      class_0       0.94      0.93      0.94       716
#     class_1+       0.85      0.87      0.86       342
#     class_2+       0.90      0.89      0.90       189
#     class_3+       0.99      0.99      0.99       753
#
#     accuracy                           0.94      2000
#    macro avg       0.92      0.92      0.92      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get the class labels
class_labels = list(test_generator.class_indices.keys())

# Compute the confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()

# %%
# Optional: Use sklearn's built-in confusion matrix display
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_labels)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix with Class Labels")
plt.show()

# %%
# Specify the path where you want to save the model
model_save_path = "/kaggle/working/custom_cnn_model_updated.h5"  # Use .h5 for HDF5 format or .tf for TensorFlow SavedModel format

# Save the trained model
model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /kaggle/working/custom_cnn_model_updated.h5

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      18,874,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           2,052 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,796,046 (220.47 MB)
#  Trainable params: 19,265,348 (73.49 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 38,530,698 (146.98 MB)

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# conv2d
# max_pooling2d
# conv2d_1
# max_pooling2d_1
# conv2d_2
# max_pooling2d_2
# conv2d_3
# max_pooling2d_3
# flatten
# dense
# dropout
# dense_1
